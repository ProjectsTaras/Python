# %% [markdown]
# # Multi-agent demo for lesson
#
# Цей ноутбук показує просту навчальну систему, у якій кілька `AI-агентів` співпрацюють над однією задачею.

# %%
from multi_agent_demo import default_scenario, MultiAgentLessonDemo, format_intro, format_block, print_conclusion

# %%
scenario = default_scenario()
demo = MultiAgentLessonDemo()
messages = demo.run(scenario)

print(format_intro(scenario))
print()
for message in messages:
    print(format_block(message))
    print()
print_conclusion(messages)
