# %% [markdown]
# # Zestaw zadań – Podstawowe operacje na tablicach NumPy
#
# Wstaw swoje rozwiązania w komórkach kodu oznaczonych `# TU ROZWIĄZANIE`.
#
# Powodzenia!

# %% [markdown]
# ## Sekcja 1 – Operacje arytmetyczne
# ### Zadanie 1
#
# Utwórz dwie tablice NumPy:
# A = [12, -4, 7, 9]
# B = [3, 6, -2, 1]
#
# Wykonaj i zapisz:
# 1. A_plus_B – dodawanie
# 2. A_minus_B – odejmowanie
# 3. A_mul_B – mnożenie
# 4. A_div_B – dzielenie

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Zadanie 2
#
# Użyj funkcji add(), subtract(), multiply(), divide() na tablicach:
# A = [[2,5,-3],[7,1,4]]
# B = [[1,2,6],[3,0,2]]

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Zadanie 3
#
# Dane tablice:
# X = [3,6,9,12,15]
# Y = [1,2,3,4,5]
#
# Oblicz:
# 1. X_squared
# 2. X_plus_10
# 3. XY_sum

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Sekcja 2 – Operacje macierzowe
# ### Zadanie 4
#
# A =
# [[1,4],
#  [2,5]]
#
# B =
# [[2,3],
#  [10,20]]
#
# Oblicz:
# 1. Dot_AB
# 2. Inner_AB

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Zadanie 5
#
# Wektory:
# v1 = [2,7,1]
# v2 = [5,3,4]
# Oblicz iloczyn skalarny.

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Zadanie 6
#
# M =
# [[0,2],
#  [1,3],
#  [4,5]]
#
# Oblicz:
# 1. M_T
# 2. M_MM = M * M_T
# 3. Rows_inner (iloczyny wierszy)
#
# M_T → transpozycja macierzy M<br>
# M_MM → macierz M pomnożona przez M_T<br>
# Rows_inner → macierz iloczynów wierszy<br>

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Sekcja 3 – Operacje statystyczne
# ### Zadanie 7
#
# T = [10,56,23,97]
#
# Oblicz:
# 1. T_mean
# 2. T_median
# 3. T_std

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Zadanie 8
#
# Wygeneruj 20 losowych liczb 0–100 (seed=10) → R
# Oblicz:
# 1. R_min
# 2. R_max
# 3. R_mean
# 4. R_std

# %%
# TU ROZWIĄZANIE
import numpy as np

rng = np.random.default_rng(10)
R = rng.integers(0, 101, size=20)

# Wpisz swoje rozwiązanie poniżej

# %% [markdown]
# ## Sekcja 4 – Zadanie końcowe
# ### Zadanie 9
#
# A =
# [[3,5,7],
#  [2,4,6]]
#
# B =
# [[1,0,2],
#  [3,1,5]]
#
# Oblicz:
# 1. A_plus_B
# 2. A_minus_B
# 3. A_mul_B
# 4. Dot_AB
# 5. A_T
# 6. Stats_A (średnia, mediana, std)

# %%
# TU ROZWIĄZANIE
import numpy as np

# Wpisz swoje rozwiązanie poniżej
